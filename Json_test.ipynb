# %%
import requests

# %%
headers = {'Authorization': 'Basic Key'}

# %%
r = requests.get("https://api.shutterstock.com/v2/images/1621031059?language=es&view=full",headers=headers)

# %%
picList = []
for i,dat in enumerate(r.json()['data']):
    while(i<11):
        pic
# Out:
# [{'id': '1622550916',
#   'aspect': 1,
#   'assets': {'preview': {'height': 450,
#     'url': 'https://image.shutterstock.com/display_pic_with_logo/1098452/1622550916/stock-photo-a-d-illustration-of-the-coronavirus-coronaviruses-are-a-large-family-of-viruses-ranging-from-the-1622550916.jpg',
#     'width': 450},
#    'small_thumb': {'height': 100,
#     'url': 'https://thumb1.shutterstock.com/thumb_small/1098452/1622550916/stock-photo-a-d-illustration-of-the-coronavirus-coronaviruses-are-a-large-family-of-viruses-ranging-from-the-1622550916.jpg',
#     'width': 100},
#    'large_thumb': {'height': 150,
#     'url': 'https://thumb1.shutterstock.com/thumb_large/1098452/1622550916/stock-photo-a-d-illustration-of-the-coronavirus-coronaviruses-are-a-large-family-of-viruses-ranging-from-the-1622550916.jpg',
#     'width': 150},
#    'huge_thumb': {'height': 260,
# ...

# %%
len(r.json()["keywords"])
# Out:
# 63
